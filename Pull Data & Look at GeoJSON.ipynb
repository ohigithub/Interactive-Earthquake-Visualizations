# %% [markdown]
# ### Look at GeoJSON Data

# %%
geo = requests.get('https://earthquake.usgs.gov/earthquakes/feed/v1.0/summary/all_week.geojson')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/24/ffrwmgdx0p71d3f671p8hl_00000gn/T/ipykernel_9036/4073920120.py in <module>
# ----> 1 geo = requests.get('https://earthquake.usgs.gov/earthquakes/feed/v1.0/summary/all_week.geojson')
#
# NameError: name 'requests' is not defined

# %%
geo.status_code
# Out:
# 200

# %%
#Inspecting JSON file

geo.json()
# Out:
# {'type': 'FeatureCollection',
#  'metadata': {'generated': 1665346297000,
#   'url': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/summary/all_week.geojson',
#   'title': 'USGS All Earthquakes, Past Week',
#   'status': 200,
#   'api': '1.10.3',
#   'count': 2071},
#  'features': [{'type': 'Feature',
#    'properties': {'mag': 1.88999999,
#     'place': '72 km ESE of Naalehu, Hawaii',
#     'time': 1665345719090,
#     'updated': 1665345914540,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/hv73172722',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/hv73172722.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 55,
#     'net': 'hv',
#     'code': '73172722',
#     'ids': ',hv73172722,',
#     'sources': ',hv,',
#     'types': ',origin,phase-data,',
#     'nst': 40,
#     'dmin': None,
#     'rms': 0.170000002,
# ...

# %%
df = pd.json_normalize(geo.json()['features'])

# %%
df.head().T
# Out:
#                                                                       0  \
# type                                                            Feature
# id                                                         ak022ctp8v8n
# properties.mag                                                      1.6
# properties.place                       27 km WSW of Petersville, Alaska
# properties.time                                           1665077472711
# properties.updated                                        1665077588732
# properties.tz                                                      None
# properties.url        https://earthquake.usgs.gov/earthquakes/eventp...
# properties.detail     https://earthquake.usgs.gov/earthquakes/feed/v...
# properties.felt                                                     NaN
# properties.cdi                                                      NaN
# properties.mmi                                                      NaN
# ...

# %%
https://leafletjs.com/examples/quick-start/
